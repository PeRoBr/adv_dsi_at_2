# %% [markdown]
# # ADV_DSI_AT2 - Prepare data for training pytorch neural network - baseline model

# %%
import pandas as pd
import numpy as np
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

from joblib import dump 
from joblib import load

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

from scipy.stats import mode
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %% [markdown]
# ## Explore Data

# %%
df = pd.read_csv('../data/processed/beer_train_set.csv')

# %%
df.head()
# Out:
#             brewery_name  review_aroma  review_appearance  review_palate  \
# 0  Avery Brewing Company           2.5                3.5            3.0
# 1  Avery Brewing Company           3.5                4.0            4.0
# 2  Avery Brewing Company           4.0                3.5            4.5
# 3  Avery Brewing Company           3.5                4.0            3.5
# 4  Avery Brewing Company           4.0                3.0            4.0
#
#    review_taste  beer_abv                beer_style
# 0           2.5       5.5  American Amber / Red Ale
# 1           4.0       5.5  American Amber / Red Ale
# 2           5.0       5.5  American Amber / Red Ale
# 3           4.0       5.5  American Amber / Red Ale
# 4           4.0       5.5  American Amber / Red Ale

# %%
df.shape
# Out:
# (7500, 7)

# %% [markdown]
# ## Prepare Data 1 - Encode target categorical variable to ordinal integer data type

# %%
df_cleaned = df.copy()

# %%
df_cleaned
# Out:
#                  brewery_name  review_aroma  review_appearance  review_palate  \
# 0       Avery Brewing Company           2.5                3.5            3.0
# 1       Avery Brewing Company           3.5                4.0            4.0
# 2       Avery Brewing Company           4.0                3.5            4.5
# 3       Avery Brewing Company           3.5                4.0            3.5
# 4       Avery Brewing Company           4.0                3.0            4.0
# ...                       ...           ...                ...            ...
# 7495  Victory Brewing Company           4.5                4.5            4.5
# 7496  Victory Brewing Company           4.0                4.0            4.0
# 7497  Victory Brewing Company           4.5                5.0            4.5
# 7498  Victory Brewing Company           4.5                4.5            5.0
# 7499  Victory Brewing Company           4.0                3.5            4.0
#
#       review_taste  beer_abv                beer_style
# 0              2.5       5.5  American Amber / Red Ale
# 1              4.0       5.5  American Amber / Red Ale
# 2              5.0       5.5  American Amber / Red Ale
# 3              4.0       5.5  American Amber / Red Ale
# 4              4.0       5.5  American Amber / Red Ale
# ...            ...       ...                       ...
# 7495           4.5       9.1    Russian Imperial Stout
# 7496           4.0       9.1    Russian Imperial Stout
# 7497           4.5       9.1    Russian Imperial Stout
# 7498           4.5       9.1    Russian Imperial Stout
# 7499           3.0       9.1    Russian Imperial Stout
#
# [7500 rows x 7 columns]

# %%
# Target variable must be converted to ordinal. Order ategories from most to least frequent, thus beer_style = 0 = American IPA = the mode of the data.
# convert to int

cats = [['American IPA', 'American Double / Imperial IPA', 'Russian Imperial Stout', 'American Pale Ale (APA)', 'American Double / Imperial Stout', 'American Strong Ale', 'American Porter', 'American Amber / Red Ale', 'Belgian Strong Dark Ale', 'Fruit / Vegetable Beer']]

col_encoder = OrdinalEncoder(categories = cats)
df_cleaned['beer_style'] = col_encoder.fit_transform(df_cleaned[['beer_style']])
df_cleaned['beer_style'] = df_cleaned['beer_style'].astype(int)

# %%
df_cleaned
# Out:
#                  brewery_name  review_aroma  review_appearance  review_palate  \
# 0       Avery Brewing Company           2.5                3.5            3.0
# 1       Avery Brewing Company           3.5                4.0            4.0
# 2       Avery Brewing Company           4.0                3.5            4.5
# 3       Avery Brewing Company           3.5                4.0            3.5
# 4       Avery Brewing Company           4.0                3.0            4.0
# ...                       ...           ...                ...            ...
# 7495  Victory Brewing Company           4.5                4.5            4.5
# 7496  Victory Brewing Company           4.0                4.0            4.0
# 7497  Victory Brewing Company           4.5                5.0            4.5
# 7498  Victory Brewing Company           4.5                4.5            5.0
# 7499  Victory Brewing Company           4.0                3.5            4.0
#
#       review_taste  beer_abv  beer_style
# 0              2.5       5.5           7
# 1              4.0       5.5           7
# 2              5.0       5.5           7
# 3              4.0       5.5           7
# 4              4.0       5.5           7
# ...            ...       ...         ...
# 7495           4.5       9.1           2
# 7496           4.0       9.1           2
# 7497           4.5       9.1           2
# 7498           4.5       9.1           2
# 7499           3.0       9.1           2
#
# [7500 rows x 7 columns]

# %% [markdown]
# ## Prepare Data 2 - Split data into train, test and validation sets

# %%
# Define a function 

def pop_target(df, target_col, to_numpy=False):
    """Extract target variable from dataframe and convert to nympy arrays if required

    Parameters
    ----------
    df : pd.DataFrame
        Dataframe
    target_col : str
        Name of the target variable
    to_numpy : bool
        Flag stating to convert to numpy array or not

    Returns
    -------
    pd.DataFrame/Numpy array
        Subsetted Pandas dataframe containing all features
    pd.DataFrame/Numpy array
        Subsetted Pandas dataframe containing the target
    """

    df_copy = df.copy()
    target = df_copy.pop(target_col)
    
    if to_numpy:
        df_copy = df_copy.to_numpy()
        target = target.to_numpy()
    
    return df_copy, target

# Define a function to split train test and validation data sets.

def split_sets_random(df, target_col, test_ratio=0.2, to_numpy=False):
    """Split sets randomly

    Parameters
    ----------
    df : pd.DataFrame
        Input dataframe
    target_col : str
        Name of the target column
    test_ratio : float
        Ratio used for the validation and testing sets (default: 0.2)

    Returns
    -------
    Numpy Array
        Features for the training set
    Numpy Array
        Target for the training set
    Numpy Array
        Features for the validation set
    Numpy Array
        Target for the validation set
    Numpy Array
        Features for the testing set
    Numpy Array
        Target for the testing set
    """
    
    from sklearn.model_selection import train_test_split
    
    features, target = pop_target(df=df, target_col=target_col, to_numpy=to_numpy)
    
    X_data, X_test, y_data, y_test = train_test_split(features, target, test_size=test_ratio, random_state=8)
    
    val_ratio = test_ratio / (1 - test_ratio)
    X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, test_size=val_ratio, random_state=8)

    return X_train, y_train, X_val, y_val, X_test, y_test

# Define a function to save train, test ad validation sets to processed data directory. 

def save_sets(X_train=None, y_train=None, X_val=None, y_val=None, X_test=None, y_test=None, path='../data/processed/'):
    """Save the different sets locally

    Parameters
    ----------
    X_train: Numpy Array
        Features for the training set
    y_train: Numpy Array
        Target for the training set
    X_val: Numpy Array
        Features for the validation set
    y_val: Numpy Array
        Target for the validation set
    X_test: Numpy Array
        Features for the testing set
    y_test: Numpy Array
        Target for the testing set
    path : str
        Path to the folder where the sets will be saved (default: '../data/processed/')

    Returns
    -------
    """
    import numpy as np

    if X_train is not None:
      np.save(f'{path}X_train', X_train)
    if X_val is not None:
      np.save(f'{path}X_val',   X_val)
    if X_test is not None:
      np.save(f'{path}X_test',  X_test)
    if y_train is not None:
      np.save(f'{path}y_train', y_train)
    if y_val is not None:
      np.save(f'{path}y_val',   y_val)
    if y_test is not None:
      np.save(f'{path}y_test',  y_test)

# %%
# split data into train, test and val sets - do not covert to numpy till final save.

X_train, y_train, X_val, y_val, X_test, y_test = split_sets_random(df_cleaned, target_col='beer_style', test_ratio=0.2, to_numpy=False)

# %%
X_train
# Out:
#                             brewery_name  review_aroma  review_appearance  \
# 2360  Boston Beer Company (Samuel Adams)           4.5                4.0
# 3815            Founders Brewing Company           4.0                4.5
# 914                 Bell's Brewery, Inc.           4.5                4.5
# 7086             Victory Brewing Company           3.5                3.5
# 135                Avery Brewing Company           5.0                4.5
# ...                                  ...           ...                ...
# 5499                          Rogue Ales           4.0                4.5
# 5074                          Rogue Ales           3.0                3.5
# 1889  Boston Beer Company (Samuel Adams)           4.0                4.0
# 7251             Victory Brewing Company           4.5                4.5
# 2265  Boston Beer Company (Samuel Adams)           3.5                4.0
#
#       review_palate  review_taste  beer_abv
# 2360            3.0           2.0       9.2
# 3815            4.5           4.5      10.5
# 914             4.5           4.5      11.5
# 7086            3.5           4.5       8.5
# 135             4.0           4.0      10.3
# ...             ...           ...       ...
# 5499            4.0           4.5      11.0
# 5074            3.5           3.0       6.4
# 1889            3.5           4.0       6.0
# 7251            4.5           5.0       5.1
# 2265            2.0           1.5       5.9
#
# [4500 rows x 6 columns]

# %% [markdown]
# ## Prepare Data 3 - Prepare training data

# %%
# list categorical variables

cat_cols = ['brewery_name']

# %%
X_train.columns
# Out:
# Index(['brewery_name', 'review_aroma', 'review_appearance', 'review_palate',
#        'review_taste', 'beer_abv'],
#       dtype='object')

# %%
# List numerical variables

num_cols = list(set(X_train.columns) - set(cat_cols))
num_cols
# Out:
# ['review_aroma',
#  'review_appearance',
#  'beer_abv',
#  'review_palate',
#  'review_taste']

# %%
X_train[num_cols]
# Out:
#       review_aroma  review_appearance  beer_abv  review_palate  review_taste
# 2360           4.5                4.0       9.2            3.0           2.0
# 3815           4.0                4.5      10.5            4.5           4.5
# 914            4.5                4.5      11.5            4.5           4.5
# 7086           3.5                3.5       8.5            3.5           4.5
# 135            5.0                4.5      10.3            4.0           4.0
# ...            ...                ...       ...            ...           ...
# 5499           4.0                4.5      11.0            4.0           4.5
# 5074           3.0                3.5       6.4            3.5           3.0
# 1889           4.0                4.0       6.0            3.5           4.0
# 7251           4.5                4.5       5.1            4.5           5.0
# 2265           3.5                4.0       5.9            2.0           1.5
#
# [4500 rows x 5 columns]

# %%
# Use default standard scaler to scale numeric cols.

sc = StandardScaler()
X_train[num_cols] = sc.fit_transform(X_train[num_cols])

# %%
X_train[num_cols]
# Out:
#       review_aroma  review_appearance  beer_abv  review_palate  review_taste
# 2360      0.964149          -0.067906  0.290530      -1.565163     -3.069606
# 3815      0.133940           0.896064  0.706344       0.971720      0.828911
# 914       0.964149           0.896064  1.026201       0.971720      0.828911
# 7086     -0.696268          -1.031877  0.066630      -0.719535      0.828911
# 135       1.794357           0.896064  0.642373       0.126092      0.049208
# ...            ...                ...       ...            ...           ...
# 5499      0.133940           0.896064  0.866273       0.126092      0.828911
# 5074     -1.526477          -1.031877 -0.605070      -0.719535     -1.510199
# 1889      0.133940          -0.067906 -0.733013      -0.719535      0.049208
# 7251      0.964149           0.896064 -1.020884       0.971720      1.608615
# 2265     -0.696268          -0.067906 -0.764999      -3.256419     -3.849309
#
# [4500 rows x 5 columns]

# %%
X_train
# Out:
#                             brewery_name  review_aroma  review_appearance  \
# 2360  Boston Beer Company (Samuel Adams)      0.964149          -0.067906
# 3815            Founders Brewing Company      0.133940           0.896064
# 914                 Bell's Brewery, Inc.      0.964149           0.896064
# 7086             Victory Brewing Company     -0.696268          -1.031877
# 135                Avery Brewing Company      1.794357           0.896064
# ...                                  ...           ...                ...
# 5499                          Rogue Ales      0.133940           0.896064
# 5074                          Rogue Ales     -1.526477          -1.031877
# 1889  Boston Beer Company (Samuel Adams)      0.133940          -0.067906
# 7251             Victory Brewing Company      0.964149           0.896064
# 2265  Boston Beer Company (Samuel Adams)     -0.696268          -0.067906
#
#       review_palate  review_taste  beer_abv
# 2360      -1.565163     -3.069606  0.290530
# 3815       0.971720      0.828911  0.706344
# 914        0.971720      0.828911  1.026201
# 7086      -0.719535      0.828911  0.066630
# 135        0.126092      0.049208  0.642373
# ...             ...           ...       ...
# 5499       0.126092      0.828911  0.866273
# 5074      -0.719535     -1.510199 -0.605070
# 1889      -0.719535      0.049208 -0.733013
# 7251       0.971720      1.608615 -1.020884
# 2265      -3.256419     -3.849309 -0.764999
#
# [4500 rows x 6 columns]

# %%
# OneHotEncode brewery_name

ohe = OneHotEncoder(sparse=False)

# OHE
X_cat = pd.DataFrame(ohe.fit_transform(X_train[cat_cols]), index = X_train.index)

# # name OHE'd columns
X_cat.columns = ohe.get_feature_names(cat_cols)

# # drop non-OHE version of column
X_train.drop(cat_cols, axis=1, inplace=True)

# # join training data to new OHE'd columns.
X = pd.concat([X_train, X_cat], axis=1)

X
# Out:
# /opt/conda/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#       review_aroma  review_appearance  review_palate  review_taste  beer_abv  \
# 2360      0.964149          -0.067906      -1.565163     -3.069606  0.290530
# 3815      0.133940           0.896064       0.971720      0.828911  0.706344
# 914       0.964149           0.896064       0.971720      0.828911  1.026201
# 7086     -0.696268          -1.031877      -0.719535      0.828911  0.066630
# 135       1.794357           0.896064       0.126092      0.049208  0.642373
# ...            ...                ...            ...           ...       ...
# 5499      0.133940           0.896064       0.126092      0.828911  0.866273
# 5074     -1.526477          -1.031877      -0.719535     -1.510199 -0.605070
# 1889      0.133940          -0.067906      -0.719535      0.049208 -0.733013
# 7251      0.964149           0.896064       0.971720      1.608615 -1.020884
# 2265     -0.696268          -0.067906      -3.256419     -3.849309 -0.764999
#
#       brewery_name_Avery Brewing Company  brewery_name_Bell's Brewery, Inc.  \
# 2360                                 0.0                                0.0
# 3815                                 0.0                                0.0
# 914                                  0.0                                1.0
# 7086                                 0.0                                0.0
# 135                                  1.0                                0.0
# ...                                  ...                                ...
# 5499                                 0.0                                0.0
# 5074                                 0.0                                0.0
# 1889                                 0.0                                0.0
# 7251                                 0.0                                0.0
# 2265                                 0.0                                0.0
#
#       brewery_name_Boston Beer Company (Samuel Adams)  \
# 2360                                              1.0
# 3815                                              0.0
# 914                                               0.0
# 7086                                              0.0
# 135                                               0.0
# ...                                               ...
# 5499                                              0.0
# 5074                                              0.0
# 1889                                              1.0
# 7251                                              0.0
# 2265                                              1.0
#
#       brewery_name_Dogfish Head Brewery  \
# 2360                                0.0
# 3815                                0.0
# 914                                 0.0
# 7086                                0.0
# 135                                 0.0
# ...                                 ...
# 5499                                0.0
# 5074                                0.0
# 1889                                0.0
# 7251                                0.0
# 2265                                0.0
#
#       brewery_name_Founders Brewing Company  \
# 2360                                    0.0
# 3815                                    1.0
# 914                                     0.0
# 7086                                    0.0
# 135                                     0.0
# ...                                     ...
# 5499                                    0.0
# 5074                                    0.0
# 1889                                    0.0
# 7251                                    0.0
# 2265                                    0.0
#
#       brewery_name_Lagunitas Brewing Company  brewery_name_Rogue Ales  \
# 2360                                     0.0                      0.0
# 3815                                     0.0                      0.0
# 914                                      0.0                      0.0
# 7086                                     0.0                      0.0
# 135                                      0.0                      0.0
# ...                                      ...                      ...
# 5499                                     0.0                      1.0
# 5074                                     0.0                      1.0
# 1889                                     0.0                      0.0
# 7251                                     0.0                      0.0
# 2265                                     0.0                      0.0
#
#       brewery_name_Sierra Nevada Brewing Co.  brewery_name_Stone Brewing Co.  \
# 2360                                     0.0                             0.0
# 3815                                     0.0                             0.0
# 914                                      0.0                             0.0
# 7086                                     0.0                             0.0
# 135                                      0.0                             0.0
# ...                                      ...                             ...
# 5499                                     0.0                             0.0
# 5074                                     0.0                             0.0
# 1889                                     0.0                             0.0
# 7251                                     0.0                             0.0
# 2265                                     0.0                             0.0
#
#       brewery_name_Victory Brewing Company
# 2360                                   0.0
# 3815                                   0.0
# 914                                    0.0
# 7086                                   1.0
# 135                                    0.0
# ...                                    ...
# 5499                                   0.0
# 5074                                   0.0
# 1889                                   0.0
# 7251                                   1.0
# 2265                                   0.0
#
# [4500 rows x 15 columns]

# %% [markdown]
# ## Prepare Data 4 - build pipeline on train data to apply to test and val data.

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
print(cat_cols)
print(num_cols)
# Out:
# ['brewery_name']
# ['review_aroma', 'review_appearance', 'beer_abv', 'review_palate', 'review_taste']

# %%
# transformer for numeric cols

num_transformer = Pipeline(
    steps=[
        ('scaler', StandardScaler())
    ]
)

# %%
# OHE for categorical cols

cat_transformer = Pipeline(
    steps=[
        ('one_hot_encoder', OneHotEncoder(sparse=False, drop='first'))
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num_cols', num_transformer, num_cols),
        ('cat_cols', cat_transformer, cat_cols)
    ]
)

# %%
dump(preprocessor,  '../models/preprocessor.joblib')
# Out:
# ['../models/preprocessor.joblib']

# %%
# split data into train, test and val sets - do not covert to numpy till final save.

X_train, y_train, X_val, y_val, X_test, y_test = split_sets_random(df_cleaned, target_col='beer_style', test_ratio=0.2, to_numpy=False)

# %%
X_train
# Out:
#                             brewery_name  review_aroma  review_appearance  \
# 2360  Boston Beer Company (Samuel Adams)           4.5                4.0
# 3815            Founders Brewing Company           4.0                4.5
# 914                 Bell's Brewery, Inc.           4.5                4.5
# 7086             Victory Brewing Company           3.5                3.5
# 135                Avery Brewing Company           5.0                4.5
# ...                                  ...           ...                ...
# 5499                          Rogue Ales           4.0                4.5
# 5074                          Rogue Ales           3.0                3.5
# 1889  Boston Beer Company (Samuel Adams)           4.0                4.0
# 7251             Victory Brewing Company           4.5                4.5
# 2265  Boston Beer Company (Samuel Adams)           3.5                4.0
#
#       review_palate  review_taste  beer_abv
# 2360            3.0           2.0       9.2
# 3815            4.5           4.5      10.5
# 914             4.5           4.5      11.5
# 7086            3.5           4.5       8.5
# 135             4.0           4.0      10.3
# ...             ...           ...       ...
# 5499            4.0           4.5      11.0
# 5074            3.5           3.0       6.4
# 1889            3.5           4.0       6.0
# 7251            4.5           5.0       5.1
# 2265            2.0           1.5       5.9
#
# [4500 rows x 6 columns]

# %%
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('num_cols',
#                                  Pipeline(steps=[('scaler', StandardScaler())]),
#                                  ['review_aroma', 'review_appearance',
#                                   'beer_abv', 'review_palate',
#                                   'review_taste']),
#                                 ('cat_cols',
#                                  Pipeline(steps=[('one_hot_encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False))]),
#                                  ['brewery_name'])])

# %%
X_train = preprocessor.transform(X_train)
X_val = preprocessor.transform(X_val)
X_test = preprocessor.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.96414881, -0.06790638,  0.29052976, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.13394031,  0.89606437,  0.70634399, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.96414881,  0.89606437,  1.02620109, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.13394031, -0.06790638, -0.73301296, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.96414881,  0.89606437, -1.02088435, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.6962682 , -0.06790638, -0.76499867, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
# Save transformed train, test and val sets

save_sets(X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, path='../data/processed/')

# %%
# define a function to convert daat to pytorch tensors

class PytorchDataset(Dataset):
    """
    Pytorch dataset
    ...

    Attributes
    ----------
    X_tensor : Pytorch tensor
        Features tensor
    y_tensor : Pytorch tensor
        Target tensor

    Methods
    -------
    __getitem__(index)
        Return features and target for a given index
    __len__
        Return the number of observations
    to_tensor(data)
        Convert Pandas Series to Pytorch tensor
    """
        
    def __init__(self, X, y):
        self.X_tensor = self.to_tensor(X)
        self.y_tensor = self.to_tensor(y)
    
    def __getitem__(self, index):
        return self.X_tensor[index], self.y_tensor[index]
        
    def __len__ (self):
        return len(self.X_tensor)
    
    def to_tensor(self, data):
        return torch.Tensor(np.array(data))

# %%
train_dataset = PytorchDataset(X=X_train, y=y_train)
val_dataset = PytorchDataset(X=X_val, y=y_val)
test_dataset = PytorchDataset(X=X_test, y=y_test)

# %%
X_train.shape[1]
# Out:
# 14

# %% [markdown]
# ## Baseline Model

# %%
# For a baseline we will predict every record as the mode of the training data.
# the beer_style categories were passed to ordinal enoder i order of most to least frequent, thus 

mode(y_train)
# Out:
# /tmp/ipykernel_5077/3021002665.py:4: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode(y_train)
# ModeResult(mode=array([1]), count=array([630]))

# %%
y_base = np.full((len(y_train), 1), 1)

# %%
accuracy_score(y_train, y_base)
# Out:
# 0.14

# %%
f1_score(y_train, y_base, average = 'weighted')
# Out:
# 0.0343859649122807

# %% [markdown]
# ## Define model architecture

# %%
class PytorchMultiClass(nn.Module):
    def __init__(self, num_features):
        super(PytorchMultiClass, self).__init__()
        
        self.layer_1 = nn.Linear(num_features, 32)
        self.layer_out = nn.Linear(32, 10)

    def forward(self, x):
        x = F.dropout(F.relu(self.layer_1(x)), training=self.training)
        return self.layer_out(x)

# %%
model = PytorchMultiClass(X_train.shape[1])

# %%
model
# Out:
# PytorchMultiClass(
#   (layer_1): Linear(in_features=14, out_features=32, bias=True)
#   (layer_out): Linear(in_features=32, out_features=10, bias=True)
# )

# %%
def get_device():
    if torch.cuda.is_available():
        device = torch.device('cuda:0')
    else:
        device = torch.device('cpu') # don't have GPU 
    return device

# %%
device = get_device()
model.to(device)
# Out:
# PytorchMultiClass(
#   (layer_1): Linear(in_features=14, out_features=32, bias=True)
#   (layer_out): Linear(in_features=32, out_features=10, bias=True)
# )

# %%
print(model)
# Out:
# PytorchMultiClass(
#   (layer_1): Linear(in_features=14, out_features=32, bias=True)
#   (layer_out): Linear(in_features=32, out_features=10, bias=True)
# )

# %% [markdown]
# ## Train Model

# %%
criterion = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

# %%
def train_classification(train_data, model, criterion, optimizer, batch_size, device, scheduler=None, generate_batch=None):
    """Train a Pytorch multi-class classification model

    Parameters
    ----------
    train_data : torch.utils.data.Dataset
        Pytorch dataset
    model: torch.nn.Module
        Pytorch Model
    criterion: function
        Loss function
    optimizer: torch.optim
        Optimizer
    bacth_size : int
        Number of observations per batch
    device : str
        Name of the device used for the model
    scheduler : torch.optim.lr_scheduler
        Pytorch Scheduler used for updating learning rate
    collate_fn : function
        Function defining required pre-processing steps

    Returns
    -------
    Float
        Loss score
    Float:
        Accuracy Score
    """
    
    # Set model to training mode
    model.train()
    train_loss = 0
    train_acc = 0
    
    # Create data loader
    data = DataLoader(train_data, batch_size=batch_size, shuffle=True, collate_fn=generate_batch)
    
    # Iterate through data by batch of observations
    for feature, target_class in data:

        # Reset gradients
        optimizer.zero_grad()
        
        # Load data to specified device
        feature, target_class = feature.to(device), target_class.to(device)
        
        # Make predictions
        output = model(feature)
        
        # Calculate loss for given batch
        loss = criterion(output, target_class.long())

        # Calculate global loss
        train_loss += loss.item()
        
        # Calculate gradients
        loss.backward()

        # Update Weights
        optimizer.step()
        
        # Calculate global accuracy
        train_acc += (output.argmax(1) == target_class).sum().item()

    # Adjust the learning rate
    if scheduler:
        scheduler.step()

    return train_loss / len(train_data), train_acc / len(train_data)

# %%
def test_classification(test_data, model, criterion, batch_size, device, generate_batch=None):
    """Calculate performance of a Pytorch multi-class classification model

    Parameters
    ----------
    test_data : torch.utils.data.Dataset
        Pytorch dataset
    model: torch.nn.Module
        Pytorch Model
    criterion: function
        Loss function
    bacth_size : int
        Number of observations per batch
    device : str
        Name of the device used for the model
    collate_fn : function
        Function defining required pre-processing steps

    Returns
    -------
    Float
        Loss score
    Float:
        Accuracy Score
    """    
    
    # Set model to evaluation mode
    model.eval()
    test_loss = 0
    test_acc = 0
    
    # Create data loader
    data = DataLoader(test_data, batch_size=batch_size, collate_fn=generate_batch)
    
    # Iterate through data by batch of observations
    for feature, target_class in data:
        
        # Load data to specified device
        feature, target_class = feature.to(device), target_class.to(device)
        
        # Set no update to gradients
        with torch.no_grad():
            
            # Make predictions
            output = model(feature)
            
            # Calculate loss for given batch
            loss = criterion(output, target_class.long())

            # Calculate global loss
            test_loss += loss.item()
            
            # Calculate global accuracy
            test_acc += (output.argmax(1) == target_class).sum().item()

    return test_loss / len(test_data), test_acc / len(test_data)

# %%
N_EPOCHS = 50
BATCH_SIZE = 32

# %%
# Solution:
# from src.models.pytorch import train_classification, test_classification

for epoch in range(N_EPOCHS):
    train_loss, train_acc = train_classification(train_dataset, model=model, criterion=criterion, optimizer=optimizer, batch_size=BATCH_SIZE, device=device)
    valid_loss, valid_acc = test_classification(test_dataset, model=model, criterion=criterion, batch_size=BATCH_SIZE, device=device)

    print(f'Epoch: {epoch}')
    print(f'\t(train)\t|\tLoss: {train_loss:.4f}\t|\tAcc: {train_acc * 100:.1f}%')
    print(f'\t(valid)\t|\tLoss: {valid_loss:.4f}\t|\tAcc: {valid_acc * 100:.1f}%')
# Out:
# Epoch: 0
# 	(train)	|	Loss: 0.0570	|	Acc: 28.3%
# 	(valid)	|	Loss: 0.0498	|	Acc: 34.7%
# Epoch: 1
# 	(train)	|	Loss: 0.0565	|	Acc: 28.4%
# 	(valid)	|	Loss: 0.0497	|	Acc: 37.9%
# Epoch: 2
# 	(train)	|	Loss: 0.0583	|	Acc: 27.9%
# 	(valid)	|	Loss: 0.0520	|	Acc: 31.7%
# Epoch: 3
# 	(train)	|	Loss: 0.0595	|	Acc: 26.1%
# 	(valid)	|	Loss: 0.0514	|	Acc: 36.7%
# Epoch: 4
# 	(train)	|	Loss: 0.0601	|	Acc: 26.7%
# 	(valid)	|	Loss: 0.0512	|	Acc: 32.9%
# Epoch: 5
# 	(train)	|	Loss: 0.0611	|	Acc: 27.5%
# 	(valid)	|	Loss: 0.0528	|	Acc: 34.2%
# Epoch: 6
# 	(train)	|	Loss: 0.0597	|	Acc: 26.2%
# 	(valid)	|	Loss: 0.0539	|	Acc: 29.8%
# Epoch: 7
# 	(train)	|	Loss: 0.0585	|	Acc: 27.0%
# 	(valid)	|	Loss: 0.0535	|	Acc: 31.5%
# Epoch: 8
# 	(train)	|	Loss: 0.0591	|	Acc: 27.3%
# 	(valid)	|	Loss: 0.0527	|	Acc: 33.1%
# Epoch: 9
# 	(train)	|	Loss: 0.0594	|	Acc: 26.5%
# 	(valid)	|	Loss: 0.0526	|	Acc: 29.8%
# Epoch: 10
# 	(train)	|	Loss: 0.0573	|	Acc: 27.0%
# 	(valid)	|	Loss: 0.0508	|	Acc: 33.9%
# Epoch: 11
# 	(train)	|	Loss: 0.0580	|	Acc: 28.0%
# 	(valid)	|	Loss: 0.0522	|	Acc: 33.8%
# Epoch: 12
# 	(train)	|	Loss: 0.0576	|	Acc: 28.9%
# 	(valid)	|	Loss: 0.0501	|	Acc: 34.5%
# Epoch: 13
# 	(train)	|	Loss: 0.0573	|	Acc: 29.4%
# 	(valid)	|	Loss: 0.0514	|	Acc: 33.6%
# Epoch: 14
# 	(train)	|	Loss: 0.0581	|	Acc: 27.4%
# 	(valid)	|	Loss: 0.0530	|	Acc: 34.3%
# Epoch: 15
# 	(train)	|	Loss: 0.0586	|	Acc: 27.9%
# 	(valid)	|	Loss: 0.0520	|	Acc: 32.7%
# Epoch: 16
# 	(train)	|	Loss: 0.0571	|	Acc: 29.1%
# 	(valid)	|	Loss: 0.0501	|	Acc: 36.2%
# Epoch: 17
# 	(train)	|	Loss: 0.0576	|	Acc: 28.0%
# 	(valid)	|	Loss: 0.0511	|	Acc: 36.3%
# Epoch: 18
# 	(train)	|	Loss: 0.0578	|	Acc: 28.0%
# 	(valid)	|	Loss: 0.0518	|	Acc: 31.2%
# Epoch: 19
# 	(train)	|	Loss: 0.0600	|	Acc: 27.0%
# 	(valid)	|	Loss: 0.0520	|	Acc: 33.7%
# Epoch: 20
# 	(train)	|	Loss: 0.0587	|	Acc: 28.6%
# 	(valid)	|	Loss: 0.0502	|	Acc: 33.5%
# Epoch: 21
# 	(train)	|	Loss: 0.0587	|	Acc: 28.5%
# 	(valid)	|	Loss: 0.0512	|	Acc: 33.1%
# Epoch: 22
# 	(train)	|	Loss: 0.0573	|	Acc: 28.7%
# 	(valid)	|	Loss: 0.0533	|	Acc: 31.3%
# Epoch: 23
# 	(train)	|	Loss: 0.0579	|	Acc: 28.3%
# 	(valid)	|	Loss: 0.0513	|	Acc: 30.9%
# Epoch: 24
# 	(train)	|	Loss: 0.0570	|	Acc: 28.3%
# 	(valid)	|	Loss: 0.0516	|	Acc: 32.3%
# Epoch: 25
# 	(train)	|	Loss: 0.0585	|	Acc: 28.3%
# 	(valid)	|	Loss: 0.0511	|	Acc: 36.0%
# Epoch: 26
# 	(train)	|	Loss: 0.0570	|	Acc: 28.4%
# 	(valid)	|	Loss: 0.0512	|	Acc: 33.1%
# Epoch: 27
# 	(train)	|	Loss: 0.0575	|	Acc: 29.1%
# 	(valid)	|	Loss: 0.0502	|	Acc: 37.1%
# Epoch: 28
# 	(train)	|	Loss: 0.0581	|	Acc: 27.8%
# 	(valid)	|	Loss: 0.0510	|	Acc: 36.0%
# Epoch: 29
# 	(train)	|	Loss: 0.0568	|	Acc: 28.8%
# 	(valid)	|	Loss: 0.0492	|	Acc: 34.9%
# Epoch: 30
# 	(train)	|	Loss: 0.0568	|	Acc: 29.3%
# 	(valid)	|	Loss: 0.0526	|	Acc: 35.9%
# Epoch: 31
# 	(train)	|	Loss: 0.0590	|	Acc: 26.7%
# 	(valid)	|	Loss: 0.0508	|	Acc: 32.7%
# Epoch: 32
# 	(train)	|	Loss: 0.0591	|	Acc: 28.3%
# 	(valid)	|	Loss: 0.0523	|	Acc: 32.7%
# Epoch: 33
# 	(train)	|	Loss: 0.0568	|	Acc: 28.4%
# 	(valid)	|	Loss: 0.0496	|	Acc: 36.5%
# Epoch: 34
# 	(train)	|	Loss: 0.0584	|	Acc: 28.8%
# 	(valid)	|	Loss: 0.0513	|	Acc: 33.7%
# Epoch: 35
# 	(train)	|	Loss: 0.0576	|	Acc: 28.2%
# 	(valid)	|	Loss: 0.0508	|	Acc: 32.3%
# Epoch: 36
# 	(train)	|	Loss: 0.0583	|	Acc: 28.8%
# 	(valid)	|	Loss: 0.0529	|	Acc: 34.8%
# Epoch: 37
# 	(train)	|	Loss: 0.0563	|	Acc: 29.0%
# 	(valid)	|	Loss: 0.0504	|	Acc: 33.9%
# Epoch: 38
# 	(train)	|	Loss: 0.0625	|	Acc: 26.8%
# 	(valid)	|	Loss: 0.0528	|	Acc: 33.1%
# Epoch: 39
# 	(train)	|	Loss: 0.0580	|	Acc: 28.0%
# 	(valid)	|	Loss: 0.0506	|	Acc: 35.9%
# Epoch: 40
# 	(train)	|	Loss: 0.0572	|	Acc: 28.4%
# 	(valid)	|	Loss: 0.0498	|	Acc: 35.6%
# Epoch: 41
# 	(train)	|	Loss: 0.0587	|	Acc: 27.8%
# 	(valid)	|	Loss: 0.0531	|	Acc: 33.9%
# Epoch: 42
# 	(train)	|	Loss: 0.0585	|	Acc: 28.0%
# 	(valid)	|	Loss: 0.0531	|	Acc: 31.7%
# Epoch: 43
# 	(train)	|	Loss: 0.0595	|	Acc: 27.8%
# 	(valid)	|	Loss: 0.0507	|	Acc: 34.7%
# Epoch: 44
# 	(train)	|	Loss: 0.0582	|	Acc: 28.1%
# 	(valid)	|	Loss: 0.0507	|	Acc: 32.5%
# Epoch: 45
# 	(train)	|	Loss: 0.0579	|	Acc: 27.5%
# 	(valid)	|	Loss: 0.0508	|	Acc: 36.1%
# Epoch: 46
# 	(train)	|	Loss: 0.0579	|	Acc: 28.1%
# 	(valid)	|	Loss: 0.0498	|	Acc: 35.7%
# Epoch: 47
# 	(train)	|	Loss: 0.0595	|	Acc: 27.7%
# 	(valid)	|	Loss: 0.0532	|	Acc: 29.9%
# Epoch: 48
# 	(train)	|	Loss: 0.0584	|	Acc: 27.3%
# 	(valid)	|	Loss: 0.0507	|	Acc: 34.7%
# Epoch: 49
# 	(train)	|	Loss: 0.0587	|	Acc: 26.8%
# 	(valid)	|	Loss: 0.0518	|	Acc: 33.1%

# %%
torch.save(model.state_dict(), "../models/pytorch_beer_classifier.pt")

# %%
model.state_dict()
# Out:
# OrderedDict([('layer_1.weight',
#               tensor([[-2.5451e-01,  9.4896e-02, -9.9060e-01, -1.6690e-02,  1.3304e-01,
#                        -2.4517e-01, -1.8805e+00, -6.7100e-01, -7.1428e-01,  4.9502e-01,
#                        -1.3625e+00,  2.3818e-01, -6.9254e-01,  9.0104e-01],
#                       [ 3.2977e-01,  1.6602e-01, -6.8277e+00, -3.3532e-01, -2.6006e-01,
#                        -1.5230e+00, -1.0201e+00, -1.9545e+00,  1.4953e+00,  1.5864e-01,
#                         4.5170e-02, -1.2735e-01, -6.2622e+00,  4.4453e-01],
#                       [ 9.0662e-01,  3.5545e-01, -1.7101e-01,  1.9386e-01,  1.4444e-01,
#                        -1.7008e+00, -9.4166e-01, -6.0781e-01, -1.7759e+00, -1.4580e+00,
#                        -1.0340e+00, -5.8091e-01, -1.8327e+00,  1.2381e+00],
#                       [ 1.0468e-01, -1.6777e-01, -7.8947e-02, -1.0421e-02,  1.1269e-01,
#                         1.7101e-01, -4.4007e-01, -7.0817e-01,  1.8587e-01, -5.9908e-01,
#                        -7.7614e-01, -4.6050e-01, -1.0279e+00, -3.1542e-01],
#                       [ 1.0607e-01,  5.1690e-01, -1.6382e-01, -3.0488e-01,  3.8152e-01,
#                        -2.5244e-01, -1.6962e-01, -1.9918e+00, -6.1621e-01, -2.9771e-01,
#                        -8.4439e-01, -2.0653e-01, -6.8744e-01,  7.0205e-03],
#                       [ 1.6958e-01, -3.5372e-02, -3.6466e-01, -7.2916e-02,  5.0304e-01,
#                        -1.0969e+00, -1.6322e+00, -3.1693e-01,  1.2404e-02, -1.4371e+00,
#                        -8.0792e-01, -8.7326e-01, -1.2693e+00, -5.2841e-01],
#                       [-2.2345e-01,  1.5240e-01,  3.4272e-01,  3.5933e-01,  1.6355e-01,
#                         3.5704e-01, -1.5391e+00, -3.3315e+00, -1.5028e+00,  7.2256e-01,
#                        -1.4272e+00, -2.2331e+00,  5.3990e-02, -1.1949e+00],
#                       [ 2.7730e-01, -1.9253e-01, -3.9201e-01, -1.6192e-01, -6.3399e-02,
#                         7.5865e-02, -8.9814e-01, -1.2906e+00, -3.7395e-02, -8.1243e-01,
#                        -7.8782e-01,  3.7986e-01, -6.5297e-01, -3.1177e-01],
#                       [-1.0451e-01,  3.4057e-01,  2.7899e-02, -2.2932e-02,  2.9345e-01,
#                        -5.3489e-01, -1.3066e+00, -6.5064e-01, -1.0079e+00, -5.9400e-01,
#                        -1.0857e+00, -2.6699e-01, -8.9559e-01, -6.3869e-01],
#                       [ 8.4685e-01,  1.2130e+00,  4.0001e-01,  2.9981e-01,  9.6357e-01,
#                        -3.2346e+00,  2.8463e+00, -3.0686e+00, -7.8537e-01, -3.0179e+00,
#                        -3.7841e-01,  2.4863e+00,  4.5676e-01, -2.6554e+00],
#                       [ 5.2530e-02, -1.6276e-02,  5.4633e-01, -1.7945e-01,  8.2184e-02,
#                        -1.4663e+00,  7.7928e-01, -3.0462e+00, -1.7130e+00,  7.6104e-01,
#                        -1.6240e-01, -6.7831e-01, -9.6022e-01,  7.0698e-02],
#                       [-1.7161e-01, -2.0805e-02,  8.7574e-02, -1.1467e-01,  8.7164e-02,
#                        -5.2971e-01, -1.1144e-01, -2.5066e-01,  1.2073e-01, -5.8713e-01,
#                        -6.2681e-01, -4.0758e-01, -8.1040e-01, -6.3593e-01],
#                       [-7.3019e-01,  3.8685e-02, -8.1899e+00,  3.5249e-01,  7.9686e-01,
#                        -1.4690e+00, -4.2782e+00,  4.8673e+00,  3.4966e+00,  1.7349e+00,
#                        -6.0080e+00,  3.8064e+00, -7.1917e+00,  6.5961e+00],
#                       [ 9.0286e-02, -5.9555e-02, -5.1321e-01,  2.2218e-01, -8.7408e-02,
#                        -1.7302e-01, -1.4308e+00, -1.0664e+00, -6.6304e-01, -4.6078e-01,
#                        -7.4474e-01, -2.7834e-01, -1.3047e-01, -9.8823e-01],
#                       [ 5.2831e-01,  1.3200e-01, -2.1044e-02, -2.1786e-02,  3.2476e-01,
#                        -6.1005e-01, -1.1526e+00, -7.3063e-01,  1.9740e-01, -1.5598e+00,
#                        -1.3216e-01, -3.8878e-01, -3.0054e-01, -8.6971e-01],
#                       [-6.7396e-02,  1.5264e-01, -6.2108e+00, -1.0683e-01, -2.7654e-01,
#                        -6.8311e-01,  1.6753e-01, -2.1433e+00,  7.1266e-01, -4.1470e-01,
#                        -6.0531e-01, -8.3439e-01, -1.6324e+00, -2.9258e+00],
#                       [-5.6707e-02,  1.0053e-02,  6.0091e-02,  2.7486e-01,  1.5761e-01,
#                        -4.2743e-01, -3.0657e-01, -7.0146e-01, -2.1577e+00, -4.4136e-01,
#                        -6.8079e-01, -3.9436e-01, -5.9500e-01, -3.7360e-01],
#                       [ 6.5682e-01, -1.0163e-01, -4.1385e-02,  4.3811e-01, -1.3265e-01,
#                        -9.2450e-01, -1.5321e+00,  4.0934e-01, -2.1112e-01, -4.6643e-01,
#                        -7.1270e-01, -5.9745e-01, -1.3379e+00, -7.7101e-01],
#                       [-3.1954e-01,  3.7202e-01, -3.2373e-01,  3.1801e-01, -2.3246e-03,
#                        -1.2021e+00,  1.3011e+00, -2.5682e+00, -7.2490e-01, -8.4312e-01,
#                        -9.1831e-01, -1.5691e-01, -7.5073e-01, -4.8542e-01],
#                       [ 4.2786e-01, -5.0856e-01, -8.3905e-01,  4.1190e-01,  1.3762e+00,
#                        -2.9347e+00, -3.0218e+00, -2.0843e+00, -6.8439e-01, -2.1529e+00,
#                        -9.3621e-01, -9.6926e-01, -3.1084e+00, -2.9648e+00],
#                       [-3.8722e-02,  4.1104e-01, -1.1796e-01,  1.5015e-01,  1.7655e-02,
#                        -7.8603e-01, -5.5672e-01, -1.2252e+00, -8.8231e-01, -8.0567e-01,
#                        -2.6693e-01, -4.1290e-01, -1.3800e+00, -1.5244e-01],
#                       [-7.0637e-03,  6.2929e-02, -9.4546e+00, -1.8393e-01,  3.9334e-02,
#                        -4.3146e+00, -3.4926e+00, -2.4543e+00, -9.2561e-01, -1.8916e+00,
#                        -7.5499e+00, -1.8265e+00, -1.5268e+00, -1.7392e+00],
#                       [-2.7638e-01,  1.0070e+00, -7.4897e+00,  2.6718e-01,  2.4623e-01,
#                         1.1418e+00,  2.3746e+00,  1.3054e+00,  3.9741e+00,  9.8036e-01,
#                         1.0870e+00,  2.6263e+00,  7.8386e-01,  2.1635e+00],
#                       [-1.3690e-01,  1.3056e-01, -8.5740e-02, -3.7563e-02,  4.0032e-01,
#                        -5.1010e-02, -7.0432e-02, -5.1242e-01, -8.7243e-01, -1.3186e-01,
#                        -3.5131e-01,  1.2173e-01, -5.2567e-01, -5.3026e-01],
#                       [-1.5532e-01,  1.3468e-01, -6.3717e+00,  3.8868e-01,  6.9334e-02,
#                        -1.0007e+00, -1.0853e+01, -3.1438e+00, -3.3741e+00, -7.6251e-01,
#                        -1.0705e+01, -6.7077e-01, -1.1367e+00, -1.1383e+00],
#                       [ 4.5334e-02, -6.9737e-02, -3.4148e-01,  2.8099e-01,  3.9212e-02,
#                        -1.3044e+00, -9.5497e-01, -3.6148e+00, -1.5621e+00, -1.8846e-01,
#                        -6.2105e-01,  2.7814e+00, -2.2450e+00, -2.1871e+00],
#                       [ 2.2767e-01,  4.3126e-01, -2.3210e+00, -1.6647e-01, -5.1329e-01,
#                        -1.4913e+00, -2.8734e+00,  2.6482e+00, -1.5932e+00, -2.5719e+00,
#                        -2.2286e+00, -2.5204e+00, -4.9536e+00,  1.5623e+00],
#                       [ 5.7390e-01, -3.8273e-01, -4.0579e-01,  3.8710e-01,  4.0054e-01,
#                        -7.7622e-01, -4.3635e+00, -2.5047e+00, -2.1385e+00, -7.6924e-01,
#                        -3.1542e+00, -1.3956e+00, -1.0358e+00,  2.7361e+00],
#                       [-4.2707e-01, -2.3303e-01, -2.0063e-01, -5.3471e-02,  6.0727e-01,
#                        -9.1868e-01, -8.6418e-01, -1.3535e+00, -7.4931e-01, -8.8408e-01,
#                        -6.9834e-01, -3.4596e-01, -1.2026e+00, -1.6479e+00],
#                       [-3.9152e-01, -1.5642e-01, -1.1534e+01, -3.9174e-01, -2.9980e-01,
#                         1.3676e+00, -5.6732e-02,  6.7639e+00,  2.8563e+00,  5.4416e+00,
#                        -4.8223e+00, -4.9059e+00, -5.8723e+00,  5.6700e+00],
#                       [-1.2715e-01,  6.8569e-01, -4.0346e-01,  1.6329e-01, -8.2591e-02,
#                        -1.7449e+00, -2.0828e+00, -1.2094e+00, -2.0581e+00, -1.0089e+00,
#                        -1.8016e+00,  7.1093e-01, -1.8938e+00, -4.9915e-01],
#                       [ 1.7403e+00,  4.0076e-01, -3.2589e+00, -5.6937e-01,  8.5253e-01,
#                        -2.9439e+00, -3.3600e+00, -2.5861e+00, -1.1294e+00, -2.4422e+00,
#                        -2.2860e+00, -3.8858e+00, -2.6386e+00, -6.1087e-01]])),
#              ('layer_1.bias',
#               tensor([ -2.4922,  -2.4068,  -4.8361,  -1.5540,  -2.8039,  -2.2057,  -4.5091,
#                        -1.9065,  -1.2394, -13.2838,  -4.8351,  -1.2336,  -9.6081,  -1.6855,
#                        -2.2923,  -2.6613,  -2.7673,  -2.5194,  -3.3484,  -8.1389,  -1.7606,
#                        -6.3942,  -7.2298,  -1.3543,  -2.8788,  -3.7743,  -9.4948,  -5.1782,
#                        -2.1122, -11.9139,  -3.9609,  -8.3434])),
#              ('layer_out.weight',
#               tensor([[ 6.6067e-01,  5.9008e-01, -4.4877e-01, -4.5569e-02,  2.6663e-01,
#                         8.2855e-01, -1.5717e+00, -1.6503e-01,  2.8317e-01,  4.9627e-01,
#                        -2.0645e+00, -1.0759e-02,  1.3968e+00, -2.4325e-02, -4.3501e-01,
#                         7.0773e-01, -9.0651e-01, -6.1057e-01,  3.6665e-01, -4.0655e-01,
#                        -4.1301e-01, -6.8288e-02,  4.9486e-01, -6.3169e-02,  6.4147e-01,
#                        -3.0141e-01, -1.2002e-01,  1.2199e-01, -2.4024e-01,  1.7791e+00,
#                        -3.8979e-01,  4.8223e-01],
#                       [-2.0298e+00, -5.0084e+00,  8.0141e-01,  4.8362e-01, -1.2465e+00,
#                        -2.1686e-01, -5.7813e-01, -2.6161e-01, -8.4377e-01, -1.3417e+00,
#                        -7.0186e-01,  3.2871e-01, -2.9537e+00, -2.9774e-01, -4.3310e-01,
#                        -3.9341e+00, -9.7665e-01,  6.1645e-01, -1.2286e+00, -6.3446e-01,
#                        -1.7848e-01, -1.1568e+01, -8.5762e+00, -4.6573e-01, -2.6153e+00,
#                        -5.2369e-02,  1.0967e-01,  6.3882e-01,  2.5294e-01, -9.7937e+00,
#                        -4.7650e-01,  9.3180e-02],
#                       [-1.1581e+00, -1.3878e+01,  8.7974e-01,  2.7320e-02,  2.3594e-01,
#                         4.9151e-02, -2.6327e-01, -6.7709e-02, -1.7762e-01,  1.1723e-02,
#                        -3.0561e-01, -1.1716e-01, -6.2842e+00,  2.1785e-01,  1.5125e-01,
#                        -1.4916e+01, -2.4684e-01, -1.0168e+00, -5.5870e-01, -2.8416e-01,
#                         4.4784e-01, -1.3989e+01, -1.9697e+01, -5.1623e-02, -1.6081e+01,
#                        -1.0139e+00, -1.4470e+00,  1.2360e+00,  3.2673e-01, -1.2422e+01,
#                        -5.6879e-01, -8.5727e-01],
#                       [ 2.9738e-01,  9.6796e-01, -8.9497e-01, -1.0041e+00, -1.2947e+00,
#                        -4.3437e-01, -2.7569e+00, -2.0327e+00, -5.2508e-01, -1.6573e+00,
#                        -2.9794e+00, -9.4814e-01,  2.0219e+00,  3.5159e-01, -1.0266e+00,
#                         7.3760e-01, -2.2579e+00,  1.7375e-01, -1.5124e+00, -5.0310e-01,
#                        -5.4740e-01,  1.3070e+00,  9.9707e-01, -1.4715e+00,  1.3180e+00,
#                         1.0355e-02,  2.0935e+00,  4.0243e-01, -1.0682e+00,  2.3584e+00,
#                        -3.7670e-01, -1.9484e+00],
#                       [ 8.4744e-02, -3.4693e+00, -1.2435e+00, -1.0232e-01, -1.0491e+00,
#                         1.2271e-01, -1.5542e-01,  1.2331e-01, -2.2675e-01, -8.0080e-01,
#                        -4.4043e-01, -3.1827e-01, -9.3811e+00, -4.0364e-01, -2.8221e-01,
#                        -2.2270e+00,  1.0257e-01,  5.2518e-01, -8.5959e-01,  4.6480e-01,
#                        -1.6975e-01, -7.4377e+00, -2.9062e+00,  5.8166e-02, -3.1460e+00,
#                         4.8776e-01, -2.5949e+00, -1.9417e+00, -3.4941e-01, -1.0193e+01,
#                         2.2895e-01, -1.9686e-01],
#                       [ 2.2825e-01, -1.0106e+00, -7.5403e-01,  2.3924e-01,  1.0679e+00,
#                         3.9836e-01,  1.4081e+00, -2.9174e-01,  4.6962e-01,  1.8656e+00,
#                         1.2605e+00,  1.1502e-01, -1.1211e+01, -2.6526e-01,  3.2572e-01,
#                        -4.5165e+00, -4.4079e-01,  3.5808e-02,  1.1448e-01,  4.5033e-02,
#                        -1.6375e-02, -5.7037e+00, -3.0011e+00,  2.3675e-01, -2.6577e+00,
#                         7.3597e-01, -2.0929e+00, -2.3801e+00, -6.8901e-01, -8.7683e+00,
#                         8.1770e-01,  1.3869e+00],
#                       [-7.3995e-01,  6.8474e-01, -6.4382e-01, -4.4450e-01, -1.2805e+00,
#                        -3.1898e-01, -1.7602e+00,  9.5403e-02, -8.2192e-02, -2.7784e+00,
#                        -1.6655e+00, -6.3302e-01,  9.4230e-01,  2.1581e-01, -4.6865e-01,
#                         6.6347e-01, -1.2012e+00, -3.9633e-01, -9.1112e-01,  2.3195e-01,
#                         1.3016e-01,  3.0272e-01,  7.0287e-01,  1.1455e-02,  1.0924e+00,
#                         6.2554e-01, -9.3771e-01, -1.0275e+00,  6.0846e-01, -7.7206e-01,
#                        -1.3966e+00, -2.8205e+00],
#                       [ 7.1440e-01,  6.7351e-01, -2.0412e+00, -3.3948e-01,  3.3999e-01,
#                        -1.9162e+00, -6.1605e-01, -5.8825e-01, -1.9395e-01, -1.6427e+00,
#                         1.1991e-01, -5.6424e-01, -5.6365e+00, -3.6847e-01, -8.8568e-01,
#                         7.7181e-01, -8.8585e-01, -3.2279e-01,  6.5799e-01, -6.9652e-01,
#                        -3.5668e-01,  1.4353e+00,  6.8970e-01, -6.5365e-01,  1.2322e+00,
#                        -1.2127e+00,  1.1879e-01, -1.6202e+00, -6.0553e-01, -1.9886e-01,
#                        -1.0508e+00, -4.2739e-01],
#                       [ 3.1488e-01, -2.7327e+00,  1.1764e+00, -2.7575e-01, -7.3486e-01,
#                         2.1198e-01,  6.4652e-01, -3.8895e-01,  8.9899e-01, -5.9816e-01,
#                         2.3005e-01, -2.6676e-01, -2.7089e+00, -1.5150e-01,  7.9995e-01,
#                        -3.0143e+00,  2.8494e-01,  5.1902e-01, -9.3729e-02,  1.4088e+00,
#                         1.3246e-01, -5.1895e+00, -5.0280e+00,  4.1381e-01, -4.1987e+00,
#                        -6.7748e-01, -2.1273e+00,  1.0654e+00, -5.2806e-01, -5.0587e+00,
#                        -4.1838e-01, -6.5715e-03],
#                       [-3.3734e-01,  7.9359e-01,  4.1769e-01, -4.1993e-01,  1.5060e-01,
#                         1.8346e-01, -1.5620e-01,  2.2629e-02, -2.8731e-01, -6.8209e-01,
#                        -3.9635e-01,  6.0119e-01, -5.0227e-01,  1.1829e-01, -5.5620e-01,
#                         7.4795e-01,  5.3514e-01,  6.6245e-01, -5.0049e-01,  1.0745e+00,
#                        -1.1976e+00,  5.8747e-01,  7.1291e-01,  5.3029e-02, -6.7827e+00,
#                        -1.8977e+00, -5.3060e-01, -1.7547e+00, -1.4440e+00,  2.9996e-01,
#                         5.6535e-01, -1.2588e+00]])),
#              ('layer_out.bias',
#               tensor([-0.1658,  1.2242,  0.8508, -1.2861,  0.7977,  0.3276, -0.8052, -1.0173,
#                        0.3721, -1.3471]))])

# %%
model.parameters()
# Out:
# <generator object Module.parameters at 0x7f2f9255db30>

# %%
test_loss, test_acc = test_classification(val_dataset, model=model, criterion=criterion, batch_size=BATCH_SIZE, device=device)
print(f'\tLoss: {test_loss:.4f}\t|\tAccuracy: {test_acc:.1f}')
# Out:
# 	Loss: 0.0515	|	Accuracy: 0.3

# %%
# make predictions on the validation data.

model.eval()
data = DataLoader(val_dataset)
for feature, target_class in data:
        
        # Load data to specified device
        feature, target_class = feature.to(device), target_class.to(device)
        
        # Set no update to gradients
        with torch.no_grad():
            
            # Make predictions
            output = model(feature)

            print(output.argmax(1))
# Out:
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([5])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([5])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([5])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([7])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([7])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([5])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([4])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([7])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([7])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([0])

# %%
model(feature)
# Out:
# tensor([[  1.1134,  -7.9846, -87.3257,   0.5617,  -4.9645,  -2.2732,   1.1192,
#            1.0500,  -6.6527,   0.8613]], grad_fn=<AddmmBackward0>)

# %%
model(feature).argmax(1)
# Out:
# tensor([6])

# %%
from starlette.responses import JSONResponse

# %%
model_test = PytorchMultiClass(14)
model_test.load_state_dict(torch.load("../models/pytorch_beer_classifier.pt"))
model_test.eval()
# Out:
# PytorchMultiClass(
#   (layer_1): Linear(in_features=14, out_features=32, bias=True)
#   (layer_out): Linear(in_features=32, out_features=10, bias=True)
# )

# %%
def format_features(brewery_name: str,	review_aroma: int, review_appearance: int, review_palate: int, review_taste: int, beer_abv: int):
    return {
        'brewery_name': [brewery_name],
        'review_aroma': [review_aroma],
        'review_appearance': [review_appearance],
        'review_palate': [review_palate],
        'review_taste': [review_taste],
        'beer_abv': [beer_abv]
    }

# %%
def predict(brewery_name: str,	review_aroma: int, review_appearance: int, review_palate: int, review_taste: int, beer_abv: int):
    features = format_features(brewery_name, review_aroma, review_appearance, review_palate, review_taste, beer_abv)
    obs = pd.DataFrame(features)
    data = preprocessor.transform(obs)
    data_tensor = torch.Tensor(np.array(data))
    pred = model_test(data_tensor).argmax(1)
    return pred
    # return JSONResponse(pred.tolist())

# %%
predict('Boston Beer Company (Samuel Adams)', 4.5, 4.0, 3.0, 2.0, 9.2)
# Out:
# tensor([1])

# %%
predict('Avery Brewing Company', 3.5, 4.0, 3.5, 4.0, 5.5)
# Out:
# tensor([7])

# %%
predict('Victory Brewing Company', 4.5, 4.5, 4.5, 5.0, 5.1)
# Out:
# tensor([3])

# %%
predict('Boston Beer Company (Samuel Adams)', 3.5, 4.0, 2.0, 1.5, 5.9)
# Out:
# tensor([9])

# %%
predict('Rogue Ales', 1.0, 5.0, 1.0, 1.0, 5.0)
# Out:
# tensor([9])

# %%
predict("Bell's Brewery, Inc.", 4.5, 4.5, 4.5, 4.5, 11.5)
# Out:
# tensor([1])
